# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"C:\Users\Siva Ramakrishna\OneDrive\Desktop\medical_cost_prediction_dataset.csv")
df
# Out:
#       age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 0      69    Male  29.4     No         1             0              0       0
# 1      32  Female  22.9     No         1             0              0       0
# 2      89    Male  25.7     No         0             0              0       0
# 3      78    Male  31.9    Yes         0             1              0       0
# 4      38    Male  27.7     No         0             0              0       0
# ...   ...     ...   ...    ...       ...           ...            ...     ...
# 4995   77  Female  19.7    Yes         0             0              0       0
# 4996   43  Female  23.9    Yes         0             0              0       0
# 4997   58  Female  31.1     No         0             0              0       0
# 4998   53    Male  27.6     No         0             0              0       0
# 4999   40    Male  25.8     No         0             0              0       0
#
# ...

# %%
df.shape
# Out:
# (5000, 20)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'bmi', 'smoker', 'diabetes', 'hypertension',
#        'heart_disease', 'asthma', 'physical_activity_level', 'daily_steps',
#        'sleep_hours', 'stress_level', 'doctor_visits_per_year',
#        'hospital_admissions', 'medication_count', 'insurance_type',
#        'insurance_coverage_pct', 'city_type', 'previous_year_cost',
#        'annual_medical_cost'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['age',
#  'gender',
#  'bmi',
#  'smoker',
#  'diabetes',
#  'hypertension',
#  'heart_disease',
#  'asthma',
#  'physical_activity_level',
#  'daily_steps',
#  'sleep_hours',
#  'stress_level',
#  'doctor_visits_per_year',
#  'hospital_admissions',
#  'medication_count',
#  'insurance_type',
#  'insurance_coverage_pct',
#  'city_type',
#  'previous_year_cost',
#  'annual_medical_cost']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      5000 non-null   int64
#  1   gender                   5000 non-null   object
#  2   bmi                      5000 non-null   float64
#  3   smoker                   5000 non-null   object
#  4   diabetes                 5000 non-null   int64
#  5   hypertension             5000 non-null   int64
#  6   heart_disease            5000 non-null   int64
#  7   asthma                   5000 non-null   int64
#  8   physical_activity_level  5000 non-null   object
#  9   daily_steps              5000 non-null   int64
#  10  sleep_hours              5000 non-null   float64
#  11  stress_level             5000 non-null   int64
#  12  doctor_visits_per_year   5000 non-null   int64
#  13  hospital_admissions      5000 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['insurance_type'].mode()
# Out:
# 0    Private
# Name: insurance_type, dtype: object

# %%
df['insurance_type'].fillna('Private',inplace = True)

# %%
df
# Out:
#       age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 0      69    Male  29.4     No         1             0              0       0
# 1      32  Female  22.9     No         1             0              0       0
# 2      89    Male  25.7     No         0             0              0       0
# 3      78    Male  31.9    Yes         0             1              0       0
# 4      38    Male  27.7     No         0             0              0       0
# ...   ...     ...   ...    ...       ...           ...            ...     ...
# 4995   77  Female  19.7    Yes         0             0              0       0
# 4996   43  Female  23.9    Yes         0             0              0       0
# 4997   58  Female  31.1     No         0             0              0       0
# 4998   53    Male  27.6     No         0             0              0       0
# 4999   40    Male  25.8     No         0             0              0       0
#
# ...

# %%
df.isna().sum()/len(df)*100
# Out:
# age                        0.0
# gender                     0.0
# bmi                        0.0
# smoker                     0.0
# diabetes                   0.0
# hypertension               0.0
# heart_disease              0.0
# asthma                     0.0
# physical_activity_level    0.0
# daily_steps                0.0
# sleep_hours                0.0
# stress_level               0.0
# doctor_visits_per_year     0.0
# hospital_admissions        0.0
# medication_count           0.0
# insurance_type             0.0
# insurance_coverage_pct     0.0
# city_type                  0.0
# previous_year_cost         0.0
# annual_medical_cost        0.0
# dtype: float64

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
plt.boxplot(df['annual_medical_cost'])
plt.show()

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      5000 non-null   int64
#  1   gender                   5000 non-null   object
#  2   bmi                      5000 non-null   float64
#  3   smoker                   5000 non-null   object
#  4   diabetes                 5000 non-null   int64
#  5   hypertension             5000 non-null   int64
#  6   heart_disease            5000 non-null   int64
#  7   asthma                   5000 non-null   int64
#  8   physical_activity_level  5000 non-null   object
#  9   daily_steps              5000 non-null   int64
#  10  sleep_hours              5000 non-null   float64
#  11  stress_level             5000 non-null   int64
#  12  doctor_visits_per_year   5000 non-null   int64
#  13  hospital_admissions      5000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                age          bmi     diabetes  hypertension  heart_disease  \
# count  5000.000000  5000.000000  5000.000000   5000.000000     5000.00000
# mean     53.299000    25.970820     0.207600      0.288000        0.14220
# std      20.646851     5.046651     0.405629      0.452876        0.34929
# min      18.000000     6.400000     0.000000      0.000000        0.00000
# 25%      36.000000    22.600000     0.000000      0.000000        0.00000
# 50%      53.000000    25.900000     0.000000      0.000000        0.00000
# 75%      71.000000    29.400000     0.000000      1.000000        0.00000
# max      89.000000    43.600000     1.000000      1.000000        1.00000
#
#             asthma   daily_steps  sleep_hours  stress_level  \
# count  5000.000000   5000.000000  5000.000000   5000.000000
# mean      0.096400   7993.216800     6.488140      5.475400
# std       0.295169   4052.127069     1.443361      2.892312
# ...

# %%
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)
IQR = Q3 - Q1
low_bun = Q1 - 1.5 * IQR
upp_bun = Q3 + 1.5 * IQR

df[(df['age']<low_bun) | (df['age']>upp_bun)]
# Out:
# Empty DataFrame
# Columns: [age, gender, bmi, smoker, diabetes, hypertension, heart_disease, asthma, physical_activity_level, daily_steps, sleep_hours, stress_level, doctor_visits_per_year, hospital_admissions, medication_count, insurance_type, insurance_coverage_pct, city_type, previous_year_cost, annual_medical_cost]
# Index: []

# %%
Q1 = df['bmi'].quantile(0.25)
Q3 = df['bmi'].quantile(0.75)
IQR = Q3 - Q1
low_bun = Q1 - 1.5 * IQR
upp_bun = Q3 + 1.5 * IQR

df[(df['bmi']<low_bun) | (df['bmi']>upp_bun)]
# Out:
#       age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 153    79    Male  12.3     No         1             0              0       1
# 208    19  Female  11.8    Yes         1             1              0       0
# 239    65    Male  40.1    Yes         1             0              0       0
# 362    51  Female  41.5     No         0             0              0       0
# 412    50    Male  40.6     No         0             1              0       0
# 473    31  Female  11.5    Yes         0             0              0       0
# 760    83    Male  12.4     No         0             1              0       0
# 916    63    Male  39.9     No         1             1              0       0
# 1304   30  Female  40.7     No         0             0              1       0
# 1457   71  Female  43.6     No         1             1              0       0
# 1662   87  Female  39.6     No         0             1              0       0
# ...

# %%
df.drop(index = df[(df['bmi']<low_bun) | (df['bmi']>upp_bun)].index,inplace = True )

# %%
Q1 = df['doctor_visits_per_year'].quantile(0.25)
Q3 = df['doctor_visits_per_year'].quantile(0.75)
IQR = Q3 - Q1
low_bun = Q1 - 1.5 * IQR
upp_bun = Q3 + 1.5 * IQR

df[(df['doctor_visits_per_year']<low_bun) | (df['doctor_visits_per_year']>upp_bun)]
# Out:
#       age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 89     45  Female  22.9     No         1             1              0       0
# 119    53  Female  29.2    Yes         0             0              0       0
# 163    19    Male  24.6     No         0             0              0       0
# 178    41    Male  31.2     No         0             0              0       0
# 264    21  Female  25.5     No         0             0              0       0
# ...   ...     ...   ...    ...       ...           ...            ...     ...
# 4740   75  Female  22.7     No         0             0              0       0
# 4759   60  Female  25.9    Yes         1             0              0       0
# 4951   49    Male  25.3    Yes         0             1              0       0
# 4965   23  Female  16.7     No         0             0              0       0
# 4975   84    Male  27.0     No         0             0              0       0
#
# ...

# %%
df
# Out:
#       age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 0      69    Male  29.4     No         1             0              0       0
# 1      32  Female  22.9     No         1             0              0       0
# 2      89    Male  25.7     No         0             0              0       0
# 3      78    Male  31.9    Yes         0             1              0       0
# 4      38    Male  27.7     No         0             0              0       0
# ...   ...     ...   ...    ...       ...           ...            ...     ...
# 4995   77  Female  19.7    Yes         0             0              0       0
# 4996   43  Female  23.9    Yes         0             0              0       0
# 4997   58  Female  31.1     No         0             0              0       0
# 4998   53    Male  27.6     No         0             0              0       0
# 4999   40    Male  25.8     No         0             0              0       0
#
# ...

# %%
Q1 = df['doctor_visits_per_year'].quantile(0.25)
Q3 = df['doctor_visits_per_year'].quantile(0.75)
IQR = Q3 - Q1
low_bun = Q1 - 1.5 * IQR
upp_bun = Q3 + 1.5 * IQR

df[(df['doctor_visits_per_year']<low_bun) | (df['doctor_visits_per_year']>upp_bun)]
# Out:
#       age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 89     45  Female  22.9     No         1             1              0       0
# 119    53  Female  29.2    Yes         0             0              0       0
# 163    19    Male  24.6     No         0             0              0       0
# 178    41    Male  31.2     No         0             0              0       0
# 264    21  Female  25.5     No         0             0              0       0
# ...   ...     ...   ...    ...       ...           ...            ...     ...
# 4740   75  Female  22.7     No         0             0              0       0
# 4759   60  Female  25.9    Yes         1             0              0       0
# 4951   49    Male  25.3    Yes         0             1              0       0
# 4965   23  Female  16.7     No         0             0              0       0
# 4975   84    Male  27.0     No         0             0              0       0
#
# ...

# %%
df.drop(index = df[(df['doctor_visits_per_year']<low_bun) | (df['doctor_visits_per_year']>upp_bun)].index,inplace = True)

# %%
Q1 = df['hospital_admissions'].quantile(0.25)
Q3 = df['hospital_admissions'].quantile(0.75)
IQR = Q3 - Q1
low_bun = Q1 - 1.5 * IQR
upp_bun = Q3 + 1.5 * IQR

df[(df['hospital_admissions']<low_bun) | (df['hospital_admissions']>upp_bun)]
# Out:
#       age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 2452   58  Female  31.9     No         1             1              0       0
# 2792   68  Female  23.8    Yes         0             0              0       1
#
#      physical_activity_level  daily_steps  sleep_hours  stress_level  \
# 2452                  Medium         8796          8.4             2
# 2792                     Low         4516          5.4             2
#
#       doctor_visits_per_year  hospital_admissions  medication_count  \
# 2452                       6                    6                 0
# 2792                       3                    6                 5
#
#      insurance_type  insurance_coverage_pct city_type  previous_year_cost  \
# 2452        Private                      74     Urban               18664
# 2792     Government                      51     Rural                5522
#
#       annual_medical_cost
# 2452             13264.21
# 2792             24416.99

# %%
df.drop(index =df[(df['hospital_admissions']<low_bun) | (df['hospital_admissions']>upp_bun)].index,inplace = True )

# %%
df['hospital_admissions'].isna().sum()
# Out:
# 0

# %%
df['doctor_visits_per_year'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# age                        0
# gender                     0
# bmi                        0
# smoker                     0
# diabetes                   0
# hypertension               0
# heart_disease              0
# asthma                     0
# physical_activity_level    0
# daily_steps                0
# sleep_hours                0
# stress_level               0
# doctor_visits_per_year     0
# hospital_admissions        0
# medication_count           0
# insurance_type             0
# insurance_coverage_pct     0
# city_type                  0
# previous_year_cost         0
# annual_medical_cost        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#                age          bmi     diabetes  hypertension  heart_disease  \
# count  4855.000000  4855.000000  4855.000000   4855.000000    4855.000000
# mean     53.273738    25.985561     0.208651      0.287539       0.141298
# std      20.643806     4.886454     0.406386      0.452661       0.348364
# min      18.000000    12.500000     0.000000      0.000000       0.000000
# 25%      36.000000    22.600000     0.000000      0.000000       0.000000
# 50%      53.000000    26.000000     0.000000      0.000000       0.000000
# 75%      71.000000    29.400000     0.000000      1.000000       0.000000
# max      89.000000    39.500000     1.000000      1.000000       1.000000
#
#             asthma   daily_steps  sleep_hours  stress_level  \
# count  4855.000000   4855.000000  4855.000000   4855.000000
# mean      0.096807   8010.503811     6.488177      5.471267
# std       0.295726   4046.482793     1.444149      2.890665
# ...

# %%
df
# Out:
#       age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 0      69    Male  29.4     No         1             0              0       0
# 1      32  Female  22.9     No         1             0              0       0
# 2      89    Male  25.7     No         0             0              0       0
# 3      78    Male  31.9    Yes         0             1              0       0
# 4      38    Male  27.7     No         0             0              0       0
# ...   ...     ...   ...    ...       ...           ...            ...     ...
# 4995   77  Female  19.7    Yes         0             0              0       0
# 4996   43  Female  23.9    Yes         0             0              0       0
# 4997   58  Female  31.1     No         0             0              0       0
# 4998   53    Male  27.6     No         0             0              0       0
# 4999   40    Male  25.8     No         0             0              0       0
#
# ...

# %%
Q1 = df['insurance_coverage_pct'].quantile(0.25)
Q3 = df['insurance_coverage_pct'].quantile(0.75)
IQR = Q3 - Q1
low_bun = Q1 - 1.5 * IQR
upp_bun = Q3 + 1.5 * IQR

df[(df['insurance_coverage_pct']<low_bun) | (df['insurance_coverage_pct']>upp_bun)]
# Out:
#       age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 2      89    Male  25.7     No         0             0              0       0
# 12     19  Female  19.3     No         0             1              0       0
# 14     77  Female  27.6    Yes         0             0              1       0
# 24     79  Female  20.8     No         0             0              0       1
# 29     72  Female  22.3     No         0             0              1       0
# ...   ...     ...   ...    ...       ...           ...            ...     ...
# 4977   25  Female  26.9     No         0             1              1       0
# 4980   26  Female  26.0     No         1             0              0       0
# 4982   88  Female  32.4    Yes         0             0              0       1
# 4993   67    Male  23.5     No         0             0              1       0
# 4996   43  Female  23.9    Yes         0             0              0       0
#
# ...

# %%
plt.hist(df['bmi'],bins = 15)
plt.title('Distribution of age')
plt.xlabel('Age values')
plt.ylabel('Frequency of age')
plt.show()

# %%
Type = df['city_type'].value_counts()

# %%
x = Type.index
y = Type.values

# %%
plt.bar(x,y, color = ["green", "darkblue", "grey"])
# Out:
# <BarContainer object of 3 artists>

# %%
level = df['physical_activity_level'].value_counts()

# %%
level
# Out:
# physical_activity_level
# Low       1941
# Medium    1929
# High       985
# Name: count, dtype: int64

# %%
x = level.index
y = level.values
plt.pie(y,labels = x,autopct = '%0.2f%%',shadow = True)
plt.show()

# %%
sns.violinplot(data = df,x = 'physical_activity_level',y='bmi' )
# Out:
# <Axes: xlabel='physical_activity_level', ylabel='bmi'>

# %%
scatter=plt.scatter(df['annual_medical_cost'],df['age'],c= df['age'],cmap = 'coolwarm')
plt.colorbar(scatter,label = 'age')

# %%
sns.stripplot(data = df,x = 'city_type',y = 'previous_year_cost')
# Out:
# <Axes: xlabel='city_type', ylabel='previous_year_cost'>

# %%
sns.countplot(data = df,x = 'gender',hue = 'physical_activity_level')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.kdeplot(data = df,x = 'previous_year_cost',hue = 'city_type',fill = True)
# Out:
# <Axes: xlabel='previous_year_cost', ylabel='Density'>

# %%
sns.boxplot(data = df,x = 'city_type',y = 'daily_steps',palette = "deep")
# Out:
# <Axes: xlabel='city_type', ylabel='daily_steps'>

# %%
sns.barplot(
    x='insurance_type',
    y='annual_medical_cost',
    data=df,
    estimator=np.mean
)
plt.title("Average Medical Cost by Insurance Type")
plt.show()

# %%
subset_features = ['age', 'bmi', 'daily_steps', 'annual_medical_cost']
sns.pairplot(df[subset_features])
plt.show()
# Out:
# C:\Users\Siva Ramakrishna\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(data = df,x ='previous_year_cost',y = 'age',hue = 'gender',kind = 'hist')

# %%
df
# Out:
#       age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 0      69    Male  29.4     No         1             0              0       0
# 1      32  Female  22.9     No         1             0              0       0
# 2      89    Male  25.7     No         0             0              0       0
# 3      78    Male  31.9    Yes         0             1              0       0
# 4      38    Male  27.7     No         0             0              0       0
# ...   ...     ...   ...    ...       ...           ...            ...     ...
# 4995   77  Female  19.7    Yes         0             0              0       0
# 4996   43  Female  23.9    Yes         0             0              0       0
# 4997   58  Female  31.1     No         0             0              0       0
# 4998   53    Male  27.6     No         0             0              0       0
# 4999   40    Male  25.8     No         0             0              0       0
#
# ...

# %%
data = df.select_dtypes(include = ["int64", "float64"])

# %%
data.corr()
# Out:
#                              age       bmi  diabetes  hypertension  \
# age                     1.000000 -0.009316  0.009938     -0.000510
# bmi                    -0.009316  1.000000  0.005003     -0.009234
# diabetes                0.009938  0.005003  1.000000     -0.019348
# hypertension           -0.000510 -0.009234 -0.019348      1.000000
# heart_disease           0.008715  0.010469 -0.008927      0.003591
# asthma                 -0.013014 -0.001798 -0.006970     -0.031000
# daily_steps             0.001075  0.002500  0.011543     -0.000615
# sleep_hours            -0.006140  0.006176 -0.014190      0.006021
# stress_level           -0.026356  0.017854  0.040968     -0.025961
# doctor_visits_per_year -0.015896 -0.016623 -0.005080     -0.007744
# hospital_admissions     0.005561  0.017423  0.003882     -0.000928
# medication_count        0.001180 -0.008844  0.010253     -0.003562
# insurance_coverage_pct  0.007053 -0.018047  0.011330     -0.001136
# ...

# %%
plt.figure(figsize = (12, 8))
sns.heatmap(round(data.corr(), 2), annot = True, cmap='coolwarm', linewidths = 0.8)
# Out:
# <Axes: >

# %%
plt.axvline(df["annual_medical_cost"].mean(), color = "green")
plt.axvline(df["annual_medical_cost"].median(), color = "red")

sns.kdeplot(df["annual_medical_cost"], fill = True, color = "orange")
# Out:
# <Axes: xlabel='annual_medical_cost', ylabel='Density'>
